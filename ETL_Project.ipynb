# %%
import pandas as pd
# Specify the file path
file_path = r"C:\Users\abdel\OneDrive\Desktop\Human Resources.csv"

# Load the CSV file into a Pandas DataFrame
Human_Resource_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print("Human Resource DataFrame:")
Human_Resource_df .head(30)
# Out:
# Human Resource DataFrame:
#                              Country  Year  Psychiatrists  Nurses  \
# 0                        Afghanistan  2016          0.231   0.098
# 1                            Albania  2016          1.471   6.876
# 2                             Angola  2016          0.057   0.660
# 3                Antigua and Barbuda  2016          1.001   7.005
# 4                          Argentina  2016         21.705     NaN
# 5                            Armenia  2016          3.840  11.245
# 6                         Azerbaijan  2016          3.452   6.717
# 7                         Bangladesh  2016          0.130   0.873
# 8                            Belarus  2016         13.504     NaN
# 9                             Belize  2016          1.392   3.340
# 10                            Bhutan  2016          0.508   0.127
# 11  Bolivia (Plurinational State of)  2016          1.128     NaN
# 12                            Brazil  2016          3.165  34.948
# ...

# %%
# Replace NaN values in specific columns with zero
columns_to_replace = ['Nurses', 'Social_workers', 'Psychologists']  # Replace with your actual column names
Human_Resource_df[columns_to_replace] = Human_Resource_df[columns_to_replace].fillna(0)

# Display the DataFrame with NaN values replaced in specific columns
Human_Resource_df.head(30)
# Out:
#                              Country  Year  Psychiatrists  Nurses  \
# 0                        Afghanistan  2016          0.231   0.098
# 1                            Albania  2016          1.471   6.876
# 2                             Angola  2016          0.057   0.660
# 3                Antigua and Barbuda  2016          1.001   7.005
# 4                          Argentina  2016         21.705   0.000
# 5                            Armenia  2016          3.840  11.245
# 6                         Azerbaijan  2016          3.452   6.717
# 7                         Bangladesh  2016          0.130   0.873
# 8                            Belarus  2016         13.504   0.000
# 9                             Belize  2016          1.392   3.340
# 10                            Bhutan  2016          0.508   0.127
# 11  Bolivia (Plurinational State of)  2016          1.128   0.000
# 12                            Brazil  2016          3.165  34.948
# ...

# %%
import pandas as pd
# Specify the file path
file_path = r"C:\Users\abdel\OneDrive\Desktop\Facilities.csv"

# Load the CSV file into a Pandas DataFrame
Facilities_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print("Facilities DataFrame:")
Facilities_df.head(30)
# Out:
# Facilities DataFrame:
#                              Country  Year  Mental _hospitals  health_units  \
# 0                        Afghanistan  2016              0.003         0.012
# 1                            Albania  2016              0.068         0.068
# 2                            Algeria  2016              0.048         0.068
# 3                             Angola  2016              0.011           NaN
# 4                Antigua and Barbuda  2016              1.001           NaN
# 5                          Argentina  2016              0.937         1.071
# 6                            Armenia  2016                NaN         0.069
# 7                         Azerbaijan  2016              0.114         0.021
# 8                         Bangladesh  2016              0.001         0.035
# 9                            Belarus  2016              0.200         0.063
# 10                            Belize  2016                NaN         1.948
# ...

# %%
# Replace NaN values in specific columns with zero
columns_to_replace = ['Mental _hospitals', 'health_units', 'outpatient _facilities','day _treatment','residential_facilities']  # Replace with your actual column names
Facilities_df[columns_to_replace] = Facilities_df[columns_to_replace].fillna(0)

# Display the DataFrame with NaN values replaced in specific columns
Facilities_df.head(30)
# Out:
#                              Country  Year  Mental _hospitals  health_units  \
# 0                        Afghanistan  2016              0.003         0.012
# 1                            Albania  2016              0.068         0.068
# 2                            Algeria  2016              0.048         0.068
# 3                             Angola  2016              0.011         0.000
# 4                Antigua and Barbuda  2016              1.001         0.000
# 5                          Argentina  2016              0.937         1.071
# 6                            Armenia  2016              0.000         0.069
# 7                         Azerbaijan  2016              0.114         0.021
# 8                         Bangladesh  2016              0.001         0.035
# 9                            Belarus  2016              0.200         0.063
# 10                            Belize  2016              0.000         1.948
# ...

# %%
# Drop the specified columns from the Facilities dataset
Facilities_df.drop(columns=['outpatient _facilities', 'day _treatment', 'residential_facilities'], inplace=True)

# Print the updated Facilities dataset
print("Updated Facilities DataFrame:")
Facilities_df.head()
# Out:
# Updated Facilities DataFrame:
#                Country  Year  Mental _hospitals  health_units
# 0          Afghanistan  2016              0.003         0.012
# 1              Albania  2016              0.068         0.068
# 2              Algeria  2016              0.048         0.068
# 3               Angola  2016              0.011         0.000
# 4  Antigua and Barbuda  2016              1.001         0.000

# %%
import pandas as pd
# Specify the file path
file_path = r"C:\Users\abdel\OneDrive\Desktop\Sub\SystemAnalysis\SA.Project\Crude suicide rates.edit.csv"

# Load the CSV file into a Pandas DataFrame
Crude_suicide_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print("Crude_suicide DataFrame:")
Crude_suicide_df.head(30)
# Out:
# Crude_suicide DataFrame:
#                 Country          Sex  over_80  over_70  over_60  over_50  \
# 0           Afghanistan   Both sexes     42.0     11.0      5.5      5.6
# 1           Afghanistan         Male     70.4     20.9      9.8      9.3
# 2           Afghanistan       Female     20.1      2.3      1.4      1.6
# 3               Albania   Both sexes     16.3      8.3      6.0      7.8
# 4               Albania         Male     23.2     11.9      8.1     11.4
# 5               Albania       Female     10.9      4.9      3.9      4.4
# 6               Algeria   Both sexes      9.4      5.6      4.2      4.1
# 7               Algeria         Male     12.7      8.4      6.2      6.2
# 8               Algeria       Female      6.4      3.0      2.2      2.0
# 9                Angola   Both sexes     63.5     42.1     23.8     14.8
# 10               Angola         Male    123.2     68.2     34.7     21.8
# ...

# %%
import pandas as pd
# Replace 'Both sexes' with 'others' in the 'Sex' column
Crude_suicide_df['Sex'] = Crude_suicide_df['Sex'].replace('Both sexes', 'others')

# Print the updated DataFrame
print("Updated Crude suicide rates DataFrame:")
print(Crude_suicide_df.head())
# Out:
# Updated Crude suicide rates DataFrame:
#        Country          Sex  over_80  over_70  over_60  over_50  over_40  \
# 0  Afghanistan   Both sexes     42.0     11.0      5.5      5.6      6.6
# 1  Afghanistan         Male     70.4     20.9      9.8      9.3     10.5
# 2  Afghanistan       Female     20.1      2.3      1.4      1.6      2.3
# 3      Albania   Both sexes     16.3      8.3      6.0      7.8      9.1
# 4      Albania         Male     23.2     11.9      8.1     11.4     13.5
#
#    over_30  over_20  over_10
# 0      9.2     10.2      3.1
# 1     15.1     16.3      4.8
# 2      2.7      3.5      1.2
# 3      6.1      6.5      5.0
# 4      8.8      6.3      3.1

# %%
# Drop the specified columns from the Facilities dataset
Crude_suicide_df.drop(columns=['over_80','over_70','over_60','over_50','over_40','over_30'], inplace=True)

# Print the updated Facilities dataset
print("Updated Facilities DataFrame:")
Crude_suicide_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 2
#       1 # Drop the specified columns from the Facilities dataset
# ----> 2 Crude_suicide_df.drop(columns=['over_80','over_70','over_60','over_50','over_40','over_30'], inplace=True)
#       4 # Print the updated Facilities dataset
#       5 print("Updated Facilities DataFrame:")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
# ...

# %%
import pandas as pd
# Replace 'Both sexes' with 'others' in the 'Sex' column
Crude_suicide_df['Sex'] = Crude_suicide_df['Sex'].replace('Both sexes', 'others')

# Print the updated DataFrame
print("Updated Crude suicide rates DataFrame:")
print(Crude_suicide_df.head())
# Out:
# Updated Crude suicide rates DataFrame:
#        Country     Sex  over_10  over_20
# 0  Afghanistan  others     10.2      3.1
# 1  Afghanistan    Male     16.3      4.8
# 2  Afghanistan  Female      3.5      1.2

# %%
import pandas as pd
# Specify the file path
file_path = r"C:\Users\abdel\OneDrive\Desktop\Age-standardized suicide rates.csv"

# Load the CSV file into a Pandas DataFrame
AgeStandardized_rates_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print("Crude_suicide DataFrame:")
AgeStandardized_rates_df.head(30)
# Out:
# Crude_suicide DataFrame:
#                 Country          Sex  2016  2015  2010  2000
# 0           Afghanistan   Both sexes   6.4   6.6   7.4   8.1
# 1           Afghanistan         Male  10.6  10.9  12.5  14.3
# 2           Afghanistan       Female   2.1   2.1   2.1   1.7
# 3               Albania   Both sexes   5.6   5.3   7.7   5.8
# 4               Albania         Male   7.0   6.7   9.5   8.2
# 5               Albania       Female   4.3   4.0   6.0   3.6
# 6               Algeria   Both sexes   3.3   3.4   3.5   4.7
# 7               Algeria         Male   4.9   5.0   5.1   6.7
# 8               Algeria       Female   1.8   1.8   1.9   2.8
# 9                Angola   Both sexes   8.9   9.3  10.4  13.9
# 10               Angola         Male  14.0  14.8  16.7  21.9
# 11               Angola       Female   4.6   4.7   5.1   7.2
# 12  Antigua and Barbuda   Both sexes   0.5   0.8   0.2   2.1
# 13  Antigua and Barbuda         Male   0.0   0.0   0.5   4.3
# ...

# %%
# Calculate the sum of values in the 'over_10' and 'over_20' columns
Crude_suicide_df['total_suicides_over_10_to_over_20_Male'] = Crude_suicide_df['over_10'] + Crude_suicide_df['over_20']

# Rank the countries based on the total number of suicides from age 10 to over 20
ranked_countries = Crude_suicide_df[['Country', 'total_suicides_over_10_to_over_20_Male']].sort_values(by='total_suicides_over_10_to_over_20_Male', ascending=False)

# Reset index for better visualization
ranked_countries.reset_index(drop=True, inplace=True)

# Print the ranked countries
print("Ranking of countries based on total number of suicides from age 10 to over 20_Male:")
ranked_countries
# Out:
# Ranking of countries based on total number of suicides from age 10 to over 20_Male:
#                  Country  total_suicides_over_10_to_over_20_Male
# 0               Kiribati                                    81.6
# 1                 Guyana                                    74.2
# 2     Russian Federation                                    68.4
# 3            El Salvador                                    67.7
# 4              Lithuania                                    63.0
# ..                   ...                                     ...
# 544             Barbados                                     0.0
# 545  Antigua and Barbuda                                     0.0
# 546  Antigua and Barbuda                                     0.0
# 547  Antigua and Barbuda                                     0.0
# 548              Grenada                                     0.0
#
# [549 rows x 2 columns]

# %%
# Check common columns in each DataFrame
common_columns = set(Human_Resource_df.columns) & set(Facilities_df.columns) & set(Crude_suicide_df.columns) & set(AgeStandardized_rates_df.columns)
print("Common columns across all DataFrames:", common_columns)

# Identify potential key columns for merging (e.g., 'Country' and 'Year')
key_columns = ['Country', 'Year']

# Merge datasets based on key columns
# For example, merging Facilities and Human Resources datasets on 'Country' and 'Year'
merged_data = pd.merge(Facilities_df, Human_Resource_df, on=key_columns, how='inner')

# Check for duplicates
duplicates = merged_data.duplicated(subset=key_columns)
print("Duplicate rows:", duplicates.sum())

# If duplicates exist, you can remove them using:
merged_data = merged_data.drop_duplicates(subset=key_columns)
merged_data.head(30)

# Explore relationships between datasets
# For example, you can analyze the correlation between suicide rates and the availability of facilities or human resources.

# You can also perform more advanced analyses such as regression models to predict suicide rates based on various factors.

# Feel free to specify the specific relationships or analyses you're interested in, and I can provide more detailed guidance.
# Out:
# Common columns across all DataFrames: {'Country'}
# Duplicate rows: 0
#                              Country  Year  Mental _hospitals  health_units  \
# 0                        Afghanistan  2016              0.003         0.012
# 1                            Albania  2016              0.068         0.068
# 2                             Angola  2016              0.011         0.000
# 3                Antigua and Barbuda  2016              1.001         0.000
# 4                          Argentina  2016              0.937         1.071
# 5                            Armenia  2016              0.000         0.069
# 6                         Azerbaijan  2016              0.114         0.021
# 7                         Bangladesh  2016              0.001         0.035
# 8                            Belarus  2016              0.200         0.063
# 9                             Belize  2016              0.000         1.948
# ...

# %%
# Remove the columns "2015", "2010", and "2000" from the DataFrame using del keyword
del AgeStandardized_rates_df['2015']
del AgeStandardized_rates_df['2010']
del AgeStandardized_rates_df['2000']

# Print the DataFrame after removing the columns
print("DataFrame after removing the columns '2015', '2010', and '2000':")
AgeStandardized_rates_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2010'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[131], line 3
# ...

# %%
import pandas as pd
# Drop the columns "2015", "2010", and "2000" from the DataFrame
AgeStandardized_rates_df.drop(columns=['2015', '2010', '2000'], inplace=True)

# Print the DataFrame after dropping the columns
print("DataFrame after dropping the columns '2015', '2010', and '2000':")
print(AgeStandardized_rates_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 3
#       1 import pandas as pd
#       2 # Drop the columns "2015", "2010", and "2000" from the DataFrame
# ----> 3 AgeStandardized_rates_df.drop(columns=['2015', '2010', '2000'], inplace=True)
#       5 # Print the DataFrame after dropping the columns
#       6 print("DataFrame after dropping the columns '2015', '2010', and '2000':")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# ...

# %%
# Drop the columns "2015", "2010", and "2000" from the DataFrame
AgeStandardized_rates_df = AgeStandardized_rates_df.drop(columns=['2015', '2010', '2000'], axes=0)

# Print the DataFrame after dropping the columns
print("DataFrame after dropping the columns '2015', '2010', and '2000':")
print(AgeStandardized_rates_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[134], line 2
#       1 # Drop the columns "2015", "2010", and "2000" from the DataFrame
# ----> 2 AgeStandardized_rates_df = AgeStandardized_rates_df.drop(columns=['2015', '2010', '2000'], axes=0)
#       4 # Print the DataFrame after dropping the columns
#       5 print("DataFrame after dropping the columns '2015', '2010', and '2000':")
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'axes'

# %%
# Sort the DataFrame based on the "2016" column from highest to lowest
sorted_df = AgeStandardized_rates_df.sort_values(by='2016', ascending=False)

# Reset index for better visualization
sorted_df.reset_index(drop=True, inplace=True)

# Print the sorted DataFrame
print("Sorted DataFrame based on the number of deaths in 2016:")
sorted_df
# Out:
# Sorted DataFrame based on the number of deaths in 2016:
#                  Country          Sex  2016  2015  2010  2000
# 0     Russian Federation         Male  48.3  49.9  62.3  85.8
# 1              Lithuania         Male  47.5  51.5  56.4  81.7
# 2                 Guyana         Male  46.6  46.6  44.9  41.2
# 3             Kazakhstan         Male  40.1  44.2  56.1  63.1
# 4                Belarus         Male  39.3  39.2  58.1  70.4
# ..                   ...          ...   ...   ...   ...   ...
# 544              Bahamas       Female   0.5   0.5   0.6   0.7
# 545  Antigua and Barbuda   Both sexes   0.5   0.8   0.2   2.1
# 546             Barbados   Both sexes   0.4   0.4   1.6   2.1
# 547             Barbados       Female   0.3   0.3   0.6   0.5
# 548  Antigua and Barbuda         Male   0.0   0.0   0.5   4.3
#
# [549 rows x 6 columns]

# %%
# Find the country with the highest number of suicides in social workers
max_suicides_social_workers = Human_Resource_df[['Country', 'Social_workers']].max()
country_with_max_suicides_social_workers = Human_Resource_df.loc[Human_Resource_df['Social_workers'] == max_suicides_social_workers['Social_workers'], 'Country'].iloc[0]

# Print the country with the highest number of suicides in social workers
print("Country with the highest number of suicides in social workers:", country_with_max_suicides_social_workers)
# Out:
# Country with the highest number of suicides in social workers: Monaco

# %%
# Sort the DataFrame by the number of suicides in social workers (descending order)
sorted_df = Human_Resource_df.sort_values(by='Social_workers', ascending=False)

# Reset index for better visualization
sorted_df.reset_index(drop=True, inplace=True)

# Print the sorted DataFrame
print("Sorted DataFrame based on the number of suicides in social workers:")
sorted_df.head()
# Out:
# Sorted DataFrame based on the number of suicides in social workers:
#                     Country  Year  Psychiatrists  Nurses  Social_workers  \
# 0                    Monaco  2016         31.326  83.536         102.592
# 1                Costa Rica  2016          3.931   5.699          76.957
# 2  United States of America  2016         10.542   4.283          60.338
# 3              Cook Islands  2016          5.731  11.462          17.193
# 4                    Panama  2016          4.031   3.452           9.221
#
#    Psychologists
# 0         53.515
# 1        142.018
# 2         29.864
# 3         11.462
# 4          7.331

# %%
# Rank the countries based on the number of suicides in social workers
ranked_df = sorted_df[['Country', 'Social_workers']]

# Reset index for better visualization
ranked_df.reset_index(drop=True, inplace=True)

# Print the ranked DataFrame
print("\nRanking of countries based on the number of suicides in social workers:")
ranked_df.head()
# Out:
# Sorted DataFrame based on the number of suicides in social workers:
#
# Ranking of countries based on the number of suicides in social workers:
#                     Country  Social_workers
# 0                    Monaco         102.592
# 1                Costa Rica          76.957
# 2  United States of America          60.338
# 3              Cook Islands          17.193
# 4                    Panama           9.221

# %%
print("Columns in AgeStandardized_rates_df:", AgeStandardized_rates_df.columns)

print("Columns in Crude_suicide_df:", Crude_suicide_df.columns)

print("Columns in merged_df:", Facilities_df.columns)

print("Columns in products_df:", sales_df.columns)
# Out:
# Columns in AgeStandardized_rates_df: Index(['Country', 'Sex', '2016', '2015', '2010', '2000'], dtype='object')
# Columns in Crude_suicide_df: Index(['Country', 'Sex', ' 80_above', ' 70to79', ' 60to69 ', ' 50to59 ',
#        ' 40to49', ' 30to39', ' 20to29', ' 10to19'],
#       dtype='object')
# Columns in Facilities_df: Index(['Country', 'Year', 'Mental _hospitals', 'health_units'], dtype='object')
# Columns in Human_Resource_df: Index(['Country', 'Year', 'Psychiatrists', 'Nurses', 'Social_workers',
#        'Psychologists'],
#       dtype='object')

# %%
# Find the maximum suicide rate in mental hospitals across all countries and years
max_mental_suicide_rate = Facilities_df['Mental _hospitals'].max()
print("Maximum suicide rate in mental hospitals:", max_mental_suicide_rate)

# Find the country/countries with the maximum suicide rate in mental hospitals
country_with_max_mental_suicide_rate = Facilities_df.loc[Facilities_df['Mental _hospitals'] == max_mental_suicide_rate, 'Country']
print("Country/Countries with the highest suicide rate in mental hospitals:")
print(country_with_max_mental_suicide_rate)
# Out:
# Maximum suicide rate in mental hospitals: 8.314
# Country/Countries with the highest suicide rate in mental hospitals:
# 50    Japan
# Name: Country, dtype: object

# %%
# Create a DataFrame with country and suicide rates in mental hospitals
mental_suicide_rates_df = Facilities_df[['Country', 'Mental _hospitals']]

# Sort the DataFrame by suicide rates in mental hospitals in descending order
sorted_mental_suicide_rates_df = mental_suicide_rates_df.sort_values(by='Mental _hospitals', ascending=False)

# Reset index for better visualization
sorted_mental_suicide_rates_df.reset_index(drop=True, inplace=True)

# Print the sorted DataFrame
print("Country/Countries with the highest suicide rate in mental hospitals:")
sorted_mental_suicide_rates_df
# Out:
# Country/Countries with the highest suicide rate in mental hospitals:
#                  Country  Mental _hospitals
# 0                  Japan              8.314
# 1               Colombia              1.988
# 2             Seychelles              1.067
# 3    Antigua and Barbuda              1.001
# 4              Argentina              0.937
# ..                   ...                ...
# 107                Congo              0.000
# 108              Hungary              0.000
# 109         Cook Islands              0.000
# 110               Guinea              0.000
# 111   Dominican Republic              0.000
#
# [112 rows x 2 columns]
