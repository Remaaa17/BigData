# %%
import pandas as pd
# Specify the file path
file_path = r"C:\Users\abdel\OneDrive\Desktop\Human Resources.csv"

# Load the CSV file into a Pandas DataFrame
Human_Resource_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print("Human Resource DataFrame:")
Human_Resource_df .head(30)
# Out:
# Human Resource DataFrame:
#                              Country  Year  Psychiatrists  Nurses  \
# 0                        Afghanistan  2016          0.231   0.098
# 1                            Albania  2016          1.471   6.876
# 2                             Angola  2016          0.057   0.660
# 3                Antigua and Barbuda  2016          1.001   7.005
# 4                          Argentina  2016         21.705     NaN
# 5                            Armenia  2016          3.840  11.245
# 6                         Azerbaijan  2016          3.452   6.717
# 7                         Bangladesh  2016          0.130   0.873
# 8                            Belarus  2016         13.504     NaN
# 9                             Belize  2016          1.392   3.340
# 10                            Bhutan  2016          0.508   0.127
# 11  Bolivia (Plurinational State of)  2016          1.128     NaN
# 12                            Brazil  2016          3.165  34.948
# ...

# %%
# Replace NaN values in specific columns with zero
columns_to_replace = ['Nurses', 'Social_workers', 'Psychologists']  # Replace with your actual column names
Human_Resource_df[columns_to_replace] = Human_Resource_df[columns_to_replace].fillna(0)

# Display the DataFrame with NaN values replaced in specific columns
Human_Resource_df.head(30)
# Out:
#                              Country  Year  Psychiatrists  Nurses  \
# 0                        Afghanistan  2016          0.231   0.098
# 1                            Albania  2016          1.471   6.876
# 2                             Angola  2016          0.057   0.660
# 3                Antigua and Barbuda  2016          1.001   7.005
# 4                          Argentina  2016         21.705   0.000
# 5                            Armenia  2016          3.840  11.245
# 6                         Azerbaijan  2016          3.452   6.717
# 7                         Bangladesh  2016          0.130   0.873
# 8                            Belarus  2016         13.504   0.000
# 9                             Belize  2016          1.392   3.340
# 10                            Bhutan  2016          0.508   0.127
# 11  Bolivia (Plurinational State of)  2016          1.128   0.000
# 12                            Brazil  2016          3.165  34.948
# ...

# %%
import pandas as pd
# Specify the file path
file_path = r"C:\Users\abdel\OneDrive\Desktop\Facilities.csv"

# Load the CSV file into a Pandas DataFrame
Facilities_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print("Facilities DataFrame:")
Facilities_df.head(30)
# Out:
# Facilities DataFrame:
#                              Country  Year  Mental _hospitals  health_units  \
# 0                        Afghanistan  2016              0.003         0.012
# 1                            Albania  2016              0.068         0.068
# 2                            Algeria  2016              0.048         0.068
# 3                             Angola  2016              0.011           NaN
# 4                Antigua and Barbuda  2016              1.001           NaN
# 5                          Argentina  2016              0.937         1.071
# 6                            Armenia  2016                NaN         0.069
# 7                         Azerbaijan  2016              0.114         0.021
# 8                         Bangladesh  2016              0.001         0.035
# 9                            Belarus  2016              0.200         0.063
# 10                            Belize  2016                NaN         1.948
# ...

# %%
import pandas as pd
# Specify the file path
file_path = r"C:\Users\abdel\OneDrive\Desktop\Age-standardized suicide rates.csv"

# Load the CSV file into a Pandas DataFrame
AgeStandardized_rates_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print("Crude_suicide DataFrame:")
AgeStandardized_rates_df.head(30)
# Out:
# Crude_suicide DataFrame:
#                 Country          Sex  2016  2015  2010  2000
# 0           Afghanistan   Both sexes   6.4   6.6   7.4   8.1
# 1           Afghanistan         Male  10.6  10.9  12.5  14.3
# 2           Afghanistan       Female   2.1   2.1   2.1   1.7
# 3               Albania   Both sexes   5.6   5.3   7.7   5.8
# 4               Albania         Male   7.0   6.7   9.5   8.2
# 5               Albania       Female   4.3   4.0   6.0   3.6
# 6               Algeria   Both sexes   3.3   3.4   3.5   4.7
# 7               Algeria         Male   4.9   5.0   5.1   6.7
# 8               Algeria       Female   1.8   1.8   1.9   2.8
# 9                Angola   Both sexes   8.9   9.3  10.4  13.9
# 10               Angola         Male  14.0  14.8  16.7  21.9
# 11               Angola       Female   4.6   4.7   5.1   7.2
# 12  Antigua and Barbuda   Both sexes   0.5   0.8   0.2   2.1
# 13  Antigua and Barbuda         Male   0.0   0.0   0.5   4.3
# ...

# %%
# Replace NaN values in specific columns with zero
columns_to_replace = ['Mental _hospitals', 'health_units', 'outpatient _facilities','day _treatment','residential_facilities']  # Replace with your actual column names
Facilities_df[columns_to_replace] = Facilities_df[columns_to_replace].fillna(0)

# Display the DataFrame with NaN values replaced in specific columns
Facilities_df.head(30)
# Out:
#                              Country  Year  Mental _hospitals  health_units  \
# 0                        Afghanistan  2016              0.003         0.012
# 1                            Albania  2016              0.068         0.068
# 2                            Algeria  2016              0.048         0.068
# 3                             Angola  2016              0.011         0.000
# 4                Antigua and Barbuda  2016              1.001         0.000
# 5                          Argentina  2016              0.937         1.071
# 6                            Armenia  2016              0.000         0.069
# 7                         Azerbaijan  2016              0.114         0.021
# 8                         Bangladesh  2016              0.001         0.035
# 9                            Belarus  2016              0.200         0.063
# 10                            Belize  2016              0.000         1.948
# ...

# %%
# Replace NaN values in specific columns with zero
columns_to_replace = ['Mental _hospitals', 'health_units', 'outpatient _facilities','day _treatment','residential_facilities']  # Replace with your actual column names
Facilities_df[columns_to_replace] = Facilities_df[columns_to_replace].fillna(0)

# Display the DataFrame with NaN values replaced in specific columns
Facilities_df.head(30)
# Out:
#                              Country  Year  Mental _hospitals  health_units  \
# 0                        Afghanistan  2016              0.003         0.012
# 1                            Albania  2016              0.068         0.068
# 2                            Algeria  2016              0.048         0.068
# 3                             Angola  2016              0.011         0.000
# 4                Antigua and Barbuda  2016              1.001         0.000
# 5                          Argentina  2016              0.937         1.071
# 6                            Armenia  2016              0.000         0.069
# 7                         Azerbaijan  2016              0.114         0.021
# 8                         Bangladesh  2016              0.001         0.035
# 9                            Belarus  2016              0.200         0.063
# 10                            Belize  2016              0.000         1.948
# ...

# %%
import pandas as pd
# Specify the file path
file_path = r"C:\Users\abdel\OneDrive\Desktop\Sub\SystemAnalysis\SA.Project\Crude suicide rates.edit.csv"

# Load the CSV file into a Pandas DataFrame
Crude_suicide_df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print("Crude_suicide DataFrame:")
Crude_suicide_df.head(30)
# Out:
# Crude_suicide DataFrame:
#                 Country          Sex  over_80  over_70  over_60  over_50  \
# 0           Afghanistan   Both sexes     42.0     11.0      5.5      5.6
# 1           Afghanistan         Male     70.4     20.9      9.8      9.3
# 2           Afghanistan       Female     20.1      2.3      1.4      1.6
# 3               Albania   Both sexes     16.3      8.3      6.0      7.8
# 4               Albania         Male     23.2     11.9      8.1     11.4
# 5               Albania       Female     10.9      4.9      3.9      4.4
# 6               Algeria   Both sexes      9.4      5.6      4.2      4.1
# 7               Algeria         Male     12.7      8.4      6.2      6.2
# 8               Algeria       Female      6.4      3.0      2.2      2.0
# 9                Angola   Both sexes     63.5     42.1     23.8     14.8
# 10               Angola         Male    123.2     68.2     34.7     21.8
# ...

# %%
# Transformation
# Merge datasets based on common columns
merged_df = pd.merge(AgeStandardized_rates_df,Crude_suicide_df, on=["Country", "Sex"], how="inner")

# Display the transformed DataFrame
print("\nTransformed DataFrame:")
merged_df

# Further transformations or analysis can be performed as needed
# Out:
# Transformed DataFrame:
#          Country          Sex  2016  2015  2010  2000  over_80  over_70  \
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1     42.0     11.0
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3     70.4     20.9
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7     20.1      2.3
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8     16.3      8.3
# 4        Albania         Male   7.0   6.7   9.5   8.2     23.2     11.9
# ..           ...          ...   ...   ...   ...   ...      ...      ...
# 544       Zambia         Male  17.5  17.4  17.9  21.9    152.1     79.0
# 545       Zambia       Female   6.2   6.1   6.2   7.5     31.2     26.4
# 546     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7    205.7     81.5
# 547     Zimbabwe         Male  29.1  28.7  32.3  35.5    285.0    111.5
# 548     Zimbabwe       Female  11.1  11.1  11.1   9.8    152.4     59.4
#
#      over_60  over_50  over_40  over_30  over_20  over_10
# ...

# %%
merged_df = pd.merge(merged_df, Facilities_df, on=["Country"], how="inner")
# Display the transformed DataFrame
print("\nTransformed DataFrame:")
merged_df
# Out:
# Transformed DataFrame:
#          Country          Sex  2016  2015  2010  2000  over_80  over_70  \
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1     42.0     11.0
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3     70.4     20.9
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7     20.1      2.3
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8     16.3      8.3
# 4        Albania         Male   7.0   6.7   9.5   8.2     23.2     11.9
# ..           ...          ...   ...   ...   ...   ...      ...      ...
# 322       Zambia         Male  17.5  17.4  17.9  21.9    152.1     79.0
# 323       Zambia       Female   6.2   6.1   6.2   7.5     31.2     26.4
# 324     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7    205.7     81.5
# 325     Zimbabwe         Male  29.1  28.7  32.3  35.5    285.0    111.5
# 326     Zimbabwe       Female  11.1  11.1  11.1   9.8    152.4     59.4
#
#      over_60  over_50  over_40  over_30  over_20  over_10  Year  \
# ...

# %%
merged_df = pd.merge(merged_df, Human_Resource_df, on=["Country", "Year"], how="inner")
# Display the transformed DataFrame
print("\nTransformed DataFrame:")
merged_df
# Out:
# Transformed DataFrame:
#          Country          Sex  2016  2015  2010  2000  over_80  over_70  \
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1     42.0     11.0
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3     70.4     20.9
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7     20.1      2.3
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8     16.3      8.3
# 4        Albania         Male   7.0   6.7   9.5   8.2     23.2     11.9
# ..           ...          ...   ...   ...   ...   ...      ...      ...
# 298       Zambia         Male  17.5  17.4  17.9  21.9    152.1     79.0
# 299       Zambia       Female   6.2   6.1   6.2   7.5     31.2     26.4
# 300     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7    205.7     81.5
# 301     Zimbabwe         Male  29.1  28.7  32.3  35.5    285.0    111.5
# 302     Zimbabwe       Female  11.1  11.1  11.1   9.8    152.4     59.4
#
#      over_60  over_50  ...  Year  Mental _hospitals  health_units  \
# ...

# %%
merged_df['Total_Suicide_Rates'] = merged_df['2016'] + merged_df['2015'] + merged_df['2010'] + merged_df['2000']
merged_df
# Out:
#          Country          Sex  2016  2015  2010  2000  over_80  over_70  \
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1     42.0     11.0
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3     70.4     20.9
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7     20.1      2.3
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8     16.3      8.3
# 4        Albania         Male   7.0   6.7   9.5   8.2     23.2     11.9
# ..           ...          ...   ...   ...   ...   ...      ...      ...
# 298       Zambia         Male  17.5  17.4  17.9  21.9    152.1     79.0
# 299       Zambia       Female   6.2   6.1   6.2   7.5     31.2     26.4
# 300     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7    205.7     81.5
# 301     Zimbabwe         Male  29.1  28.7  32.3  35.5    285.0    111.5
# 302     Zimbabwe       Female  11.1  11.1  11.1   9.8    152.4     59.4
#
#      over_60  over_50  ...  Mental _hospitals  health_units  \
# ...

# %%
merged_df['Suicide_Rates_per_Mental_Hospitals'] = merged_df['Mental _hospitals'] / merged_df['Total_Suicide_Rates']
merged_df
# Out:
#          Country          Sex  2016  2015  2010  2000  over_80  over_70  \
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1     42.0     11.0
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3     70.4     20.9
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7     20.1      2.3
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8     16.3      8.3
# 4        Albania         Male   7.0   6.7   9.5   8.2     23.2     11.9
# ..           ...          ...   ...   ...   ...   ...      ...      ...
# 298       Zambia         Male  17.5  17.4  17.9  21.9    152.1     79.0
# 299       Zambia       Female   6.2   6.1   6.2   7.5     31.2     26.4
# 300     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7    205.7     81.5
# 301     Zimbabwe         Male  29.1  28.7  32.3  35.5    285.0    111.5
# 302     Zimbabwe       Female  11.1  11.1  11.1   9.8    152.4     59.4
#
#      over_60  over_50  ...  health_units  outpatient _facilities  \
# ...

# %%
merged_df['Nurses_to_Psychiatrists_Ratio'] = merged_df['Nurses'] / merged_df['Psychiatrists']
merged_df
# Out:
#          Country          Sex  2016  2015  2010  2000  over_80  over_70  \
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1     42.0     11.0
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3     70.4     20.9
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7     20.1      2.3
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8     16.3      8.3
# 4        Albania         Male   7.0   6.7   9.5   8.2     23.2     11.9
# ..           ...          ...   ...   ...   ...   ...      ...      ...
# 298       Zambia         Male  17.5  17.4  17.9  21.9    152.1     79.0
# 299       Zambia       Female   6.2   6.1   6.2   7.5     31.2     26.4
# 300     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7    205.7     81.5
# 301     Zimbabwe         Male  29.1  28.7  32.3  35.5    285.0    111.5
# 302     Zimbabwe       Female  11.1  11.1  11.1   9.8    152.4     59.4
#
#      over_60  over_50  ...  outpatient _facilities  day _treatment  \
# ...

# %%
merged_df['Average_Suicide_Rates'] = merged_df[['2016', '2015', '2010', '2000']].mean(axis=1)
merged_df
# Out:
#          Country          Sex  2016  2015  2010  2000  over_80  over_70  \
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1     42.0     11.0
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3     70.4     20.9
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7     20.1      2.3
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8     16.3      8.3
# 4        Albania         Male   7.0   6.7   9.5   8.2     23.2     11.9
# ..           ...          ...   ...   ...   ...   ...      ...      ...
# 298       Zambia         Male  17.5  17.4  17.9  21.9    152.1     79.0
# 299       Zambia       Female   6.2   6.1   6.2   7.5     31.2     26.4
# 300     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7    205.7     81.5
# 301     Zimbabwe         Male  29.1  28.7  32.3  35.5    285.0    111.5
# 302     Zimbabwe       Female  11.1  11.1  11.1   9.8    152.4     59.4
#
#      over_60  over_50  ...  day _treatment  residential_facilities  \
# ...

# %%
merged_df['Normalized_Nurses'] = merged_df['Nurses'] / merged_df['Nurses'].max()
merged_df['Normalized_Psychiatrists'] = merged_df['Psychiatrists'] / merged_df['Psychiatrists'].max()
merged_df
# Out:
#          Country          Sex  2016  2015  2010  2000  over_80  over_70  \
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1     42.0     11.0
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3     70.4     20.9
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7     20.1      2.3
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8     16.3      8.3
# 4        Albania         Male   7.0   6.7   9.5   8.2     23.2     11.9
# ..           ...          ...   ...   ...   ...   ...      ...      ...
# 298       Zambia         Male  17.5  17.4  17.9  21.9    152.1     79.0
# 299       Zambia       Female   6.2   6.1   6.2   7.5     31.2     26.4
# 300     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7    205.7     81.5
# 301     Zimbabwe         Male  29.1  28.7  32.3  35.5    285.0    111.5
# 302     Zimbabwe       Female  11.1  11.1  11.1   9.8    152.4     59.4
#
#      over_60  over_50  ...  Psychiatrists  Nurses  Social_workers  \
# ...

# %%
merged_df['Has_Day_Treatment_Facilities'] = merged_df['day _treatment'].apply(lambda x: 1 if x > 0 else 0)
merged_df
# Out:
#          Country          Sex  2016  2015  2010  2000  over_80  over_70  \
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1     42.0     11.0
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3     70.4     20.9
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7     20.1      2.3
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8     16.3      8.3
# 4        Albania         Male   7.0   6.7   9.5   8.2     23.2     11.9
# ..           ...          ...   ...   ...   ...   ...      ...      ...
# 298       Zambia         Male  17.5  17.4  17.9  21.9    152.1     79.0
# 299       Zambia       Female   6.2   6.1   6.2   7.5     31.2     26.4
# 300     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7    205.7     81.5
# 301     Zimbabwe         Male  29.1  28.7  32.3  35.5    285.0    111.5
# 302     Zimbabwe       Female  11.1  11.1  11.1   9.8    152.4     59.4
#
#      over_60  over_50  ...  Nurses  Social_workers  Psychologists  \
# ...

# %%
age_groups = ['over_10', 'over_20', 'over_30', 'over_40', 'over_50', 'over_60', 'over_70', 'over_80']
for age_group in age_groups:
    merged_df[f'Suicide_Rates_{age_group}_Age_Group'] = merged_df[f'{age_group}']
merged_df
# Out:
#          Country          Sex  2016  2015  2010  2000  over_80  over_70  \
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1     42.0     11.0
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3     70.4     20.9
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7     20.1      2.3
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8     16.3      8.3
# 4        Albania         Male   7.0   6.7   9.5   8.2     23.2     11.9
# ..           ...          ...   ...   ...   ...   ...      ...      ...
# 298       Zambia         Male  17.5  17.4  17.9  21.9    152.1     79.0
# 299       Zambia       Female   6.2   6.1   6.2   7.5     31.2     26.4
# 300     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7    205.7     81.5
# 301     Zimbabwe         Male  29.1  28.7  32.3  35.5    285.0    111.5
# 302     Zimbabwe       Female  11.1  11.1  11.1   9.8    152.4     59.4
#
#      over_60  over_50  ...  Normalized_Psychiatrists  \
# ...

# %%
threshold_high_suicide = 15  # Define a threshold for high suicide rates
merged_df['High_Suicide_Rates'] = (merged_df['Average_Suicide_Rates'] > threshold_high_suicide).astype(int)
merged_df
# Out:
#          Country          Sex  2016  2015  2010  2000  over_80  over_70  \
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1     42.0     11.0
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3     70.4     20.9
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7     20.1      2.3
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8     16.3      8.3
# 4        Albania         Male   7.0   6.7   9.5   8.2     23.2     11.9
# ..           ...          ...   ...   ...   ...   ...      ...      ...
# 298       Zambia         Male  17.5  17.4  17.9  21.9    152.1     79.0
# 299       Zambia       Female   6.2   6.1   6.2   7.5     31.2     26.4
# 300     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7    205.7     81.5
# 301     Zimbabwe         Male  29.1  28.7  32.3  35.5    285.0    111.5
# 302     Zimbabwe       Female  11.1  11.1  11.1   9.8    152.4     59.4
#
#      over_60  over_50  ...  Has_Day_Treatment_Facilities  \
# ...

# %%
merged_df['Suicide_Rates_Change'] = merged_df['2016'] - merged_df['2000']
merged_df
# Out:
#          Country          Sex  2016  2015  2010  2000  over_80  over_70  \
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1     42.0     11.0
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3     70.4     20.9
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7     20.1      2.3
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8     16.3      8.3
# 4        Albania         Male   7.0   6.7   9.5   8.2     23.2     11.9
# ..           ...          ...   ...   ...   ...   ...      ...      ...
# 298       Zambia         Male  17.5  17.4  17.9  21.9    152.1     79.0
# 299       Zambia       Female   6.2   6.1   6.2   7.5     31.2     26.4
# 300     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7    205.7     81.5
# 301     Zimbabwe         Male  29.1  28.7  32.3  35.5    285.0    111.5
# 302     Zimbabwe       Female  11.1  11.1  11.1   9.8    152.4     59.4
#
#      over_60  over_50  ...  Suicide_Rates_over_10_Age_Group  \
# ...

# %%
merged_df['Running_Total_Suicide_Rates'] = merged_df.groupby('Country')['Total_Suicide_Rates'].cumsum()
merged_df
# Out:
#          Country          Sex  2016  2015  2010  2000  over_80  over_70  \
# 0    Afghanistan   Both sexes   6.4   6.6   7.4   8.1     42.0     11.0
# 1    Afghanistan         Male  10.6  10.9  12.5  14.3     70.4     20.9
# 2    Afghanistan       Female   2.1   2.1   2.1   1.7     20.1      2.3
# 3        Albania   Both sexes   5.6   5.3   7.7   5.8     16.3      8.3
# 4        Albania         Male   7.0   6.7   9.5   8.2     23.2     11.9
# ..           ...          ...   ...   ...   ...   ...      ...      ...
# 298       Zambia         Male  17.5  17.4  17.9  21.9    152.1     79.0
# 299       Zambia       Female   6.2   6.1   6.2   7.5     31.2     26.4
# 300     Zimbabwe   Both sexes  19.1  18.9  20.6  21.7    205.7     81.5
# 301     Zimbabwe         Male  29.1  28.7  32.3  35.5    285.0    111.5
# 302     Zimbabwe       Female  11.1  11.1  11.1   9.8    152.4     59.4
#
#      over_60  over_50  ...  Suicide_Rates_over_20_Age_Group  \
# ...

# %%
selected_columns = ['Country','Sex','Total_Suicide_Rates', 'Suicide_Rates_per_Mental_Hospitals', 'Nurses_to_Psychiatrists_Ratio', 'Average_Suicide_Rates', 'Normalized_Nurses', 'Normalized_Psychiatrists','Has_Day_Treatment_Facilities']
Result_df = merged_df[selected_columns]
Result_df
# Out:
#          Country          Sex  Total_Suicide_Rates  \
# 0    Afghanistan   Both sexes                 28.5
# 1    Afghanistan         Male                 48.3
# 2    Afghanistan       Female                  8.0
# 3        Albania   Both sexes                 24.4
# 4        Albania         Male                 31.4
# ..           ...          ...                  ...
# 298       Zambia         Male                 74.7
# 299       Zambia       Female                 26.0
# 300     Zimbabwe   Both sexes                 80.3
# 301     Zimbabwe         Male                125.6
# 302     Zimbabwe       Female                 43.1
#
#      Suicide_Rates_per_Mental_Hospitals  Nurses_to_Psychiatrists_Ratio  \
# 0                              0.000105                       0.424242
# 1                              0.000062                       0.424242
# 2                              0.000375                       0.424242
# ...

# %%
##Load the transformed data into a new CSV file
output_csv_file = "Result_df.csv"
Result_df.to_csv(output_csv_file, index=False)

# %%
# Print each column name in a separate line
print("Columns in merged_df:")
for column in merged_df.columns:
    print(column)
# Out:
# Columns in merged_df:
# Country
# Sex
# 2016
# 2015
# 2010
# 2000
# over_80
# over_70
# over_60
# over_50
# over_40
# over_30
# over_20
# over_10
# Year
# Mental _hospitals
# health_units
# outpatient _facilities
# day _treatment
# residential_facilities
# Psychiatrists
# Nurses
# Social_workers
# Psychologists
# Total_Suicide_Rates
# Suicide_Rates_per_Mental_Hospitals
# Nurses_to_Psychiatrists_Ratio
# Average_Suicide_Rates
# Normalized_Nurses
# Normalized_Psychiatrists
# Has_Day_Treatment_Facilities
# Suicide_Rates_over_10_Age_Group
# Suicide_Rates_over_20_Age_Group
# Suicide_Rates_over_30_Age_Group
# Suicide_Rates_over_40_Age_Group
# Suicide_Rates_over_50_Age_Group
# Suicide_Rates_over_60_Age_Group
# Suicide_Rates_over_70_Age_Group
# Suicide_Rates_over_80_Age_Group
# High_Suicide_Rates
# Suicide_Rates_Change
# Running_Total_Suicide_Rates

# %%
# Replace the placeholders with your actual database connection details
conn = psycopg2.connect(database="Records", user="postgres", password="root", host="127.0.0.1", port="5433")
print("Database connection opened.")
cur = conn.cursor()

# Your DataFrame named Result_df should be defined before this point
# For example: Result_df = pd.DataFrame({'column1': [1, 2, 3], 'column2': ['a', 'b', 'c']})

# Specify the table name
table_name = 'Result'

# Load the DataFrame into the PostgreSQL table
Result_df.to_sql(name=table_name, con=conn, index=False, if_exists='replace')  # Use 'replace' if you want to overwrite the table

# Close the database connection
conn.close()
# Out:
# Database connection opened.
# C:\Users\abdel\AppData\Local\Temp\ipykernel_22692\962360938.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   Result_df.to_sql(name=table_name, con=conn, index=False, if_exists='replace')  # Use 'replace' if you want to overwrite the table
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2262, in SQLiteDatabase.execute(self, sql, params)
#    2261 try:
# -> 2262     cur.execute(sql, *args)
#    2263     return cur
#
# SyntaxError: syntax error at or near ";"
# LINE 8:             AND name=?;
#                               ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import psycopg2
from psycopg2 import sql
import csv

# Replace with your database connection details
conn = psycopg2.connect(database="Records", user="postgres", password="root", host="127.0.0.1", port="5433")
print("Database connection opened.")
cur = conn.cursor()

# Replace with your CSV file path and table name
csv_file_path = 'Result_df.csv'
table_name = 'Results'

# Open the CSV file
with open(csv_file_path, 'r') as f:
    # Check if the table exists
    cur.execute(sql.SQL("""
        SELECT EXISTS (
            SELECT 1
            FROM information_schema.tables
            WHERE table_name = {table_name}
        );
    """).format(table_name=sql.Literal(table_name)))

    table_exists = cur.fetchone()[0]

    # If the table doesn't exist, create it
    if not table_exists:
        cur.execute(sql.SQL("""
            CREATE TABLE {table_name} (col1 INT, col2 TEXT, col3 FLOAT);  -- Adjust column types as needed
        """).format(table_name=sql.Identifier(table_name)))

    # Create a temporary table
    cur.execute(sql.SQL("""
        CREATE TEMPORARY TABLE temp_table AS 
        SELECT * FROM {table_name} 
        WITH NO DATA;
    """).format(table_name=sql.Identifier(table_name)))

    # Copy the data from the CSV file to the temporary table
    cur.copy_expert(sql.SQL("""
        COPY temp_table FROM STDIN WITH CSV HEADER;
    """), f)

    # Insert the data from the temporary table into the main table
    cur.execute(sql.SQL("""
        INSERT INTO {table_name} SELECT * FROM temp_table;
    """).format(table_name=sql.Identifier(table_name)))

# Commit the transaction
conn.commit()

# Close the cursor and connection
cur.close()
conn.close()

print("Data loaded into the PostgreSQL table '{table_name}' successfully.")
# Out:
# Database connection opened.
# ---------------------------------------------------------------------------
# BadCopyFileFormat                         Traceback (most recent call last)
# Cell In[32], line 41
#      34 cur.execute(sql.SQL("""
#      35     CREATE TEMPORARY TABLE temp_table AS
#      36     SELECT * FROM {table_name}
#      37     WITH NO DATA;
#      38 """).format(table_name=sql.Identifier(table_name)))
#      40 # Copy the data from the CSV file to the temporary table
# ---> 41 cur.copy_expert(sql.SQL("""
#      42     COPY temp_table FROM STDIN WITH CSV HEADER;
#      43 """), f)
#      45 # Insert the data from the temporary table into the main table
#      46 cur.execute(sql.SQL("""
#      47     INSERT INTO {table_name} SELECT * FROM temp_table;
#      48 """).format(table_name=sql.Identifier(table_name)))
#
# BadCopyFileFormat: extra data after last expected column
# ...

# %%
import pandas as pd
import psycopg2

# Replace the placeholders with your actual database connection details
conn = psycopg2.connect(database="Records", user="postgres", password="root", host="127.0.0.1", port="5433")
print("Database connection opened.")
cur = conn.cursor()

# Load the CSV file into a DataFrame
Result_df = pd.read_csv('Result_df.csv')

# Specify the table name
table_name = 'Result'

# Load the DataFrame into the PostgreSQL table
Result_df.to_sql(name=table_name, con=conn, index=False, if_exists='replace')  # Use 'replace' if you want to overwrite the table

# Close the database connection
conn.close()
# Out:
# Database connection opened.
# C:\Users\abdel\AppData\Local\Temp\ipykernel_22692\3759772103.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   Result_df.to_sql(name=table_name, con=conn, index=False, if_exists='replace')  # Use 'replace' if you want to overwrite the table
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2262, in SQLiteDatabase.execute(self, sql, params)
#    2261 try:
# -> 2262     cur.execute(sql, *args)
#    2263     return cur
#
# SyntaxError: syntax error at or near ";"
# LINE 8:             AND name=?;
#                               ^
#
#
# The above exception was the direct cause of the following exception:
#
# ...
